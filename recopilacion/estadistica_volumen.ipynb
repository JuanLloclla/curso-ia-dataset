# %%
import pandas as pd

df = pd.read_csv("../2020-Apr.csv")

print("=== ESTADÍSTICAS GENERALES ===")
print(f"Total de interacciones: {len(df):,}")
print(f"Usuarios únicos: {df['user_id'].nunique():,}")
print(f"Productos únicos: {df['product_id'].nunique():,}")s
print(f"Sesiones únicas: {df['user_session'].nunique():,}")
print(f"Rango temporal: {df['event_time'].min()} → {df['event_time'].max()}")
print(f"Promedio interacciones por usuario: {len(df) / df['user_id'].nunique():.2f}")
# Out:
# === ESTADÍSTICAS GENERALES ===
# Total de interacciones: 66,589,268
# Usuarios únicos: 4,509,623
# Productos únicos: 263,503
# Sesiones únicas: 11,652,261
# Rango temporal: 2020-04-01 00:00:00 UTC → 2020-04-30 23:59:59 UTC
# Promedio interacciones por usuario: 14.77
